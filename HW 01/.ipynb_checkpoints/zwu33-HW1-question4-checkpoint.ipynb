# %%
import numpy as np
import scipy
from scipy import spatial
# Line 3: 1: Manhattan distance
def M(target, ls):
    result = []
    for elem in ls:
        result.append(spatial.distance.cityblock(target,elem))
    return result

# %%
# Line 3: 2: Euclidean distance
def E(target, ls):
    result = []
    for elem in ls:
        result.append(spatial.distance.minkowski(target,elem,2))
    return result

# %%
# Line 3: 3: Supremum distance
def S(target, ls):
    result = []
    for elem in ls:
        result.append(spatial.distance.minkowski(target,elem,np.inf))
    return result

# %%
# Line 3: 4: Cosine similarity

# from sklearn.metrics.pairwise import cosine_similarity
def C(target, ls):
    result = []
    for elem in ls:
        result.append(spatial.distance.cosine(target,elem))
    return result

# %%
def distance(target,ls,idx):
    if(idx == 1):
        return M(target,ls)
    elif(idx == 2):
        return E(target,ls)
    elif(idx == 3):
        return S(target,ls)
    elif(idx == 4):
        return C(target,ls)

from sklearn.preprocessing import MinMaxScaler

def standardize(ls):
    return MinMaxScaler().fit_transform(ls)

from sklearn.decomposition import PCA
from matplotlib import pyplot as plt

def pca(std):  
    sklearn_pca = PCA(n_components=X)
    sklearn_pca.fit(data_std)
    result = sklearn_pca.transform(data_std)
    var_exp = sklearn_pca.explained_variance_
    # cum_var_exp = np.cumsum(var_exp)
    print("var_sum:", sum(var_exp[1:]))
    return result

# %%
import copy

fp = 'Q4-analysis-input.in'
dataSet = []
D = 0
N = 0
distance_matrix = 0
X = 0
P = []

raw_data = open(fp).read()
#raw_data = raw_data.split('\n')

raw_data = [n.split() for n in raw_data.split('\n')] 

for i in range(len(raw_data)):
    for j in range(len(raw_data[i])):
        raw_data[i][j] = int(raw_data[i][j])

D = raw_data[0][0]
N = raw_data[1][0]
distance_matrix = raw_data[2][0]
X = raw_data[3][0]
print("D: ",D,";\nN: ",N,";\ndistance_matrix:", distance_matrix,";\nX:",X)

for i in range(N + 1):
    if len(raw_data[i + 4])!= 0:
        dataSet.append(raw_data[i + 4])   


data_std = copy.deepcopy(dataSet)
# Out:
# D:  10000 ;
# N:  100 ;
# distance_matrix: 4 ;
# X: 100

# %%
if(X != -1):
    #data_std = standardize(dataSet)
    data_std = pca(data_std)  

P = data_std[0] 
result = distance(P,data_std[1:],distance_matrix)
# Out:
# var_sum: 35128582.68441384

# %%
# Make a list of (eigenvalue, eigenvector) tuples
result_pairs = [(result[i], i + 1) for i in range(len(result))]

# sort by index
import heapq
heapq.heapify(result_pairs)

print(result_pairs)
last_five = []
for i in range(5):
    last_five.append(heapq.heappop(result_pairs))

file = open('output','w') 

for i in range(5):
    file.write(str(last_five[i][1]))
    file.write('; ')
cum = sum(last_five[:5][0])
if(X != -1):
    file.write("\n")
    file.write(str("%.4f" % cum))
file.close()
# Out:
# [(0.10392983044458703, 54), (0.10861451571897307, 19), (0.11365126087810984, 56), (0.1487774910153894, 70), (0.11718425007293387, 94), (0.20765985177357915, 27), (0.15981689581448721, 7), (0.16089398760722418, 8), (0.19004254133324028, 75), (0.16814500033075164, 86), (0.12765904946316264, 46), (1.1544937385738434, 48), (1.1235188033331789, 6), (0.22448617599431808, 14), (0.18014683538342813, 62), (0.20670250691899894, 16), (1.0919583594929383, 68), (1.1021380683079476, 37), (0.2726620160167986, 79), (0.268774534678057, 82), (1.1919497729993145, 10), (0.1561664844301227, 22), (0.1284331261890982, 95), (1.1765465730273046, 12), (1.223680189587825, 50), (1.1405824399809181, 53), (1.224684747638169, 3), (1.2402115405629561, 1), (0.23124924939646607, 29), (1.2202801165521229, 61), (0.19190909727344496, 63), (1.2027027762935165, 64), (1.1188641301759985, 67), (1.1740623263619623, 69), (1.2272425732556873, 35), (1.140438240945712, 36), (1.2616043229008689, 74), (1.2287647033950164, 38), (1.2727616888093665, 9), (1.2266099569757976, 80), (1.237156802233457, 41), (1.294651963771287, 42), (1.1962809927656246, 87), (0.19218355436939094, 44), (0.20534352902578268, 91), (1.193892614694061, 11), (0.17482522984839766, 5), (1.2132806381381296, 96), (1.2932178978804574, 99), (1.2613403976975441, 100), (1.2369240287100882, 51), (1.295258382409764, 52), (1.2999454532024086, 26), (1.295253341992941, 13), (1.252641394733866, 55), (1.300203610368478, 28), (1.2948535551766427, 57), (1.162791407159353, 58), (1.3452675163033692, 59), (1.2686682541904164, 60), (1.2717612723429936, 30), (1.214294826200923, 31), (1.152960636546875, 15), (1.2916450810049858, 32), (1.2130984500512945, 65), (1.209660933250132, 66), (1.3807174837219522, 33), (1.221557706937599, 34), (1.2890373576053786, 2), (1.2599666018374507, 17), (1.262204200875167, 71), (1.3236646543991146, 72), (1.2027668550781445, 73), (1.33308231323914, 4), (1.3006812520586626, 18), (1.2471798394334552, 76), (1.2631634241876553, 77), (1.2743742032036038, 78), (1.3118006083105644, 39), (1.2601809915213662, 40), (1.2658337493019798, 81), (1.2710627946803807, 20), (1.2980268843482707, 83), (1.335169302025557, 84), (1.3389656902467324, 85), (1.303760100359681, 43), (1.2763041101562531, 21), (1.2994944347989632, 88), (1.205721963255199, 89), (1.2070999359493064, 90), (1.2765190472297285, 45), (1.318673695261475, 92), (1.2363220318273096, 93), (1.2438944762846833, 47), (1.2831036514766214, 23), (1.2616441102387312, 24), (1.2422891882804594, 97), (1.3222660526161818, 98), (1.3225600525192918, 49), (1.2707657624195976, 25)]

# %%
# use for hw result output
import heapq

x_list = [-1,100,10,2,1]

for x in x_list:
    for i in range(1,5): 
        distance_matrix = i
        X = x
        print("D: ",D,";\nN: ",N,";\ndistance_matrix:", distance_matrix,";\nX:",X)

        if(X != -1):
            # data_std = standardize(dataSet)
            data_std = pca(data_std)
        P = data_std[0] 
        result = distance(P,data_std[1:],distance_matrix)
        # Make a list of (eigenvalue, eigenvector) tuples
        result_pairs = [(result[i], i + 1) for i in range(len(result))]
        # sort by index

        heapq.heapify(result_pairs)

        last_five = []
        for i in range(5):
            last_five.append(heapq.heappop(result_pairs))

        for i in range(5):
            print(last_five[i][1],",")
        print("##################################")
# if(X != -1):
       #     print("var: ", str("%.4f" % cum))
        data_std = copy.deepcopy(dataSet)
# Out:
# D:  10000 ;
# N:  100 ;
# distance_matrix: 1 ;
# X: -1
# 54 ,
# 19 ,
# 94 ,
# 46 ,
# 56 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 2 ;
# X: -1
# 54 ,
# 19 ,
# 56 ,
# 94 ,
# 46 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 3 ;
# X: -1
# 86 ,
# 16 ,
# 75 ,
# 79 ,
# 29 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 4 ;
# X: -1
# 54 ,
# 19 ,
# 56 ,
# 94 ,
# 46 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 1 ;
# X: 100
# var_sum: 356.5375830046469
# 19 ,
# 94 ,
# 56 ,
# 95 ,
# 46 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 2 ;
# X: 100
# var_sum: 356.5375830046469
# 19 ,
# 94 ,
# 46 ,
# 95 ,
# 56 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 3 ;
# X: 100
# var_sum: 356.5375830046469
# 46 ,
# 54 ,
# 79 ,
# 8 ,
# 14 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 4 ;
# X: 100
# var_sum: 356.5375830046469
# 19 ,
# 54 ,
# 94 ,
# 56 ,
# 95 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 1 ;
# X: 10
# var_sum: 188.62637109959996
# 19 ,
# 46 ,
# 94 ,
# 70 ,
# 54 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 2 ;
# X: 10
# var_sum: 188.62629550710233
# 19 ,
# 46 ,
# 94 ,
# 70 ,
# 54 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 3 ;
# X: 10
# var_sum: 188.62637391734918
# 19 ,
# 94 ,
# 46 ,
# 70 ,
# 54 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 4 ;
# X: 10
# var_sum: 188.6261905869165
# 19 ,
# 46 ,
# 94 ,
# 54 ,
# 70 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 1 ;
# X: 2
# var_sum: 79.94932681630159
# 70 ,
# 94 ,
# 19 ,
# 16 ,
# 75 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 2 ;
# X: 2
# var_sum: 79.94932681630145
# 70 ,
# 94 ,
# 16 ,
# 19 ,
# 75 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 3 ;
# X: 2
# var_sum: 79.94932681630152
# 70 ,
# 94 ,
# 16 ,
# 19 ,
# 75 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 4 ;
# X: 2
# var_sum: 79.94932681630158
# 70 ,
# 16 ,
# 75 ,
# 94 ,
# 19 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 1 ;
# X: 1
# var_sum: 0
# 70 ,
# 16 ,
# 75 ,
# 54 ,
# 94 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 2 ;
# X: 1
# var_sum: 0
# 70 ,
# 16 ,
# 75 ,
# 54 ,
# 94 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 3 ;
# X: 1
# var_sum: 0
# 70 ,
# 16 ,
# 75 ,
# 54 ,
# 94 ,
# ##################################
# D:  10000 ;
# N:  100 ;
# distance_matrix: 4 ;
# X: 1
# var_sum: 0
# 7 ,
# 9 ,
# 14 ,
# 16 ,
# 19 ,
# ##################################

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.19.1
